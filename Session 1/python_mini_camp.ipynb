# %% [markdown]
# # Python Mini Camp
# In this section, we will efficiently cover the basic Python knowledge. With this, you can quickly understand the codes and build upon the fundamentals.

# %% [markdown]
# ## Numbers

# %%
42
# Out:
# 42

# %%
1 + 5
# Out:
# 6

# %%
print(42)
# Out:
# 42

# %% [markdown]
# ## Variable

# %%
num_stocks = 20

# %%
num_stocks
# Out:
# 20

# %%
print(num_stocks)
# Out:
# 20

# %%
my_int = 6
nasdaq_perf = 0.03
print(f'value: {my_int}, type: {type(my_int)}, nasdaq:{nasdaq_perf}')
# Out:
# value: 6, type: <class 'int'>, nasdaq:0.03

# %% [markdown]
# ## float vs interger (int)

# %%
my_float = 6.27335
print('value: {}, type: {}'.format(my_float, type(my_float)))
# Out:
# value: 6.27335, type: <class 'float'>

# %%
print(1/2)
# Out:
# 0.5

# %%
1/3
# Out:
# 0.3333333333333333

# %% [markdown]
# Note that division of `int`s produces `float`:

# %% [markdown]
# ## power `**`

# %%
1.01 ** 365
# Out:
# 37.78343433288728

# %%
print(1 + 2**2 * 3 / 6)
print((1 + 2**2) * 3 / 6)
# Out:
# 3.0
# 2.5

# %% [markdown]
# ## Strings
# strings are like words, or names

# %%
cross_corr = []
string_var = "FINA5270"
num_var = 42

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("write")
# Out:
# write

# %%
print("The federal reserve again raises the federal fund's rate by 50BPS")
# Out:
# The federal reserve again raises the federal fund's rate by 50BPS

# %% [markdown]
# ## List

# %%
my_empty_list = []
my_empty_list
# Out:
# []

# %%
list_of_ints = [1, 2, 6, 7]
print(list_of_ints)
# Out:
# [1, 2, 6, 7]

# %%
len(list_of_ints)
# Out:
# 4

# %%
type(list_of_ints)
# Out:
# list

# %%
SP500 = ['AAPL', 'FB', 'GOOGL']
SP500_returns_by_stock = [-0.02, 0.003, 0.01]

# %%
coordinates = [[12.0, 13.3], [0.6, 18.0], [88.0, 1.1]]  # two dimensional list

# %% [markdown]
# ## Accessing values

# %%
my_list = ['Python', 'is', 'still', 'cool']
print(my_list[0])
print(my_list[3])
# Out:
# Python
# cool

# %%
some_list = [1, 2, 3, 5, 8, 13, 21, 34, 55]
print(some_list[0])
print(some_list[-1])
print(some_list[5])
print(some_list[0:5])
print(some_list[0:-1])
print(some_list[0:])
# Out:
# 1
# 55
# 13
# [1, 2, 3, 5, 8]
# [1, 2, 3, 5, 8, 13, 21, 34]
# [1, 2, 3, 5, 8, 13, 21, 34, 55]

# %%
my_list = [0, 1, 2, 3, 4, 5]
my_list[0] = 99
print(my_list)

# remove first value
del my_list[0]
print(my_list)

# %% [markdown]
# ## Checking if certain value is present in list

# %%
languages = ['Java', 'C++', 'Go', 'Python', 'JavaScript']
if 'Python' in languages:
    print('Python is there!')
# Out:
# Python is there!

# %%
if 6 not in [1, 2, 3, 7]:
    print('number 6 is not present')

# %% [markdown]
# ## List are mutable

# %%
original = [1, 2, 3]
modified = original
modified[0] = 99
print('original: {}, modified: {}'.format(original, modified))
# Out:
# original: [99, 2, 3], modified: [99, 2, 3]

# %% [markdown]
# You can get around this by creating new `list`:

# %%
original = [1, 2, 3]
modified = list(original)  # Note list()
# Alternatively, you can use copy method
# modified = original.copy()
modified[0] = 99
print('original: {}, modified: {}'.format(original, modified))

# %% [markdown]
# ## `list.append()`

# %%
my_list = [1]
my_list.append('ham')
print(my_list)

# %% [markdown]
# # Conditionals

# %% [markdown]
# ## Testing truth value

# %%
Bob_Age = 39

# %%
Bob_Age == 30
# Out:
# False

# %%
Bob_Age == 39
# Out:
# True

# %%
fed_annc = 'raise'
#if fed_annc == 'raise':

# %% [markdown]
# ### `==, !=, >, <, >=, <=`

# %%
print('1 == 0: {}'.format(1 == 0))
print('1 != 0: {}'.format(1 != 0))
print('1 > 0: {}'.format(1 > 0))
print('1 > 1: {}'.format(1 > 1))
print('1 < 0: {}'.format(1 < 0))
print('1 < 1: {}'.format(1 < 1))
print('1 >= 0: {}'.format(1 >= 0))
print('1 >= 1: {}'.format(1 >= 1))
print('1 <= 0: {}'.format(1 <= 0))
print('1 <= 1: {}'.format(1 <= 1))
# Out:
# 1 == 0: False
# 1 != 0: True
# 1 > 0: True
# 1 > 1: False
# 1 < 0: False
# 1 < 1: False
# 1 >= 0: True
# 1 >= 1: True
# 1 <= 0: False
# 1 <= 1: True

# %% [markdown]
# ### `and, or, not`

# %%
Fed_Raise = True
portfolio_recommendation = False
empty_list = []
secret_value = 3.14

# %%
secret_value < 3
portfolio_recommendation == True
# Out:
# False

# %%
print(f"See if the portfolio is recommended: {portfolio_recommendation}")
# Out:
# See if the portfolio is recommended: False

# %% [markdown]
# ## `if`

# %%
Fed_raise_rates = False
if Fed_raise_rates:
    print('statement is True')

if not Fed_raise_rates:
    print('statement is not True')
# Out:
# statement is not True

# %%
empty_list = []
# With if and elif, conversion to `bool` is implicit
if empty_list:
    print('empty list')  # this won't be executed

# %%
zoom_perf = 0.04
if zoom_perf >= 0.03:
  print('enter_position')
else:
  print('do nothing')
# Out:
# do nothing

# %%
val = 3
if 0 <= val < 1 or val == 3:
    print('Value is positive and less than one or value is three')

# %% [markdown]
# ## `if-else`

# %%
portfolio_company_num = 50
if portfolio_company_num > 20:
  print("Well-diversified")
else:
  print("Concentrated")
# Out:
# not too bad

# %% [markdown]
# ## `if-elif-else`

# %%
val = -88
if val >= 100:
    print('value is equal or greater than 100')
elif val > 10:
    print('value is greater than 10 but less than 100')
else:
    print('value is equal or less than 10')

# %% [markdown]
# In-Class Exercise 1
# This is conducted for FINA5270

# %%
samsung_apple_spread = -0.5
if samsung_apple_spread > 0.2:
  print("enter pair short")
elif samsung_apple_spread < -0.2:
  print("enter pair long")
else:
  print("ignore signal")
# Out:
# enter pair long

# %% [markdown]
# ## Looping lists

# %%
comp_list = ['apple', 'meta','google','nvidia','netflix']

for item in comp_list:
    print(item)
# Out:
# apple
# meta
# google
# nvidia
# netflix

# %% [markdown]
# ### `break`
# Stop the execution of the loop.

# %%
for item in comp_list:
    if item == 'nvidia':
        print(item)
        break
# Out:
# nvidia

# %% [markdown]
# ### `enumerate()`
# In case you need to also know the index:

# %%
fictional_list = [2, 3, 4, 5, 6, 7]
fictional_list[0]
# Out:
# 2

# %%
for idx, val in enumerate(fictional_list):
    print('idx: {}, value: {}'.format(idx, val))
# Out:
# idx: 0, value: 2
# idx: 1, value: 3
# idx: 2, value: 4
# idx: 3, value: 5
# idx: 4, value: 6
# idx: 5, value: 7

# %% [markdown]
# ## `range()`

# %%
fic_num = 100
period_return = [1.01, 0.99, 1.05, 1.005]
for i in range(len(period_return)):
    fic_num = fic_num * period_return[i]
    print(fic_num)
# Out:
# 101.0
# 99.99
# 104.98949999999999
# 105.51444749999997

# %% [markdown]
# # Functions

# %%
def my_first_function(): # this function says hello world
    print('Hello world!')

# %%
my_first_function()  # Calling a function
# Out:
# Hello world!

# %% [markdown]
# ### Arguments

# %%
def simple_compute(num1, num2):
  answer = num1 * num2
  print(answer)

# %%
num1 = 48
num2 = 666
simple_compute(num1, num2)
simple_compute(59.7, 23.9)
simple_compute(159.7, 123.9)
simple_compute(359.7, 323.9)
simple_compute(4059.7, 4023.9)
simple_compute(35559.7, 3023.9)
# Out:
# 31968
# 1426.83
# 19786.829999999998
# 116506.82999999999
# 16335826.83
# 107528976.83

# %% [markdown]
# ## import function to use
#
# **NumPy**: NumPy is a fundamental Python package for scientific computing that provides support for large, multi-dimensional arrays and matrices, along with a wide range of mathematical functions to operate on these arrays. It is widely used in data analysis, machine learning, and scientific research.
#
# **Pandas**: Pandas is a library that provides data manipulation tools for analyzing and cleaning data in Python. It provides functionality for data loading, cleaning, transformation, and exploration. Pandas is often used to work with structured data in data analysis and data science workflows.
#
# **Matplotlib**: Matplotlib is a plotting library that provides a wide variety of static, animated, and interactive visualizations in Python. It is widely used to create publication-quality graphs and figures for data exploration and presentation.
#
# **Scikit-learn**: Scikit-learn is a powerful and widely-used library for machine learning in Python. It provides a range of tools for classification, regression, clustering, and dimensionality reduction, as well as tools for model selection, evaluation, and validation.
#
# **TensorFlow/ Pytorch**: TensorFlow is a powerful open-source machine learning library developed by Google. It provides a range of tools for building and training deep learning models, including neural networks and other types of models. TensorFlow can be used for a wide range of applications, including computer vision, natural language processing, and reinforcement learning.

# %%
import numpy as np

# %%
# Function with return value
def annualized_volility(daily_vol):
    annual_vol= daily_vol*np.sqrt(252)
    return annual_vol

# %%
annual_vol1 = annualized_volility(0.02)
print(annual_vol1)

annual_vol2 = annualized_volility(0.035)
print(annual_vol2)
# Out:
# 0.3174901573277509
# 0.5556077753235641

# %%
def my_fancy_calculation(first, second, third):
    return first + second - third

print(my_fancy_calculation(3, 2, 1))

print(my_fancy_calculation(first=3, second=2, third=1))

# With keyword arguments you can mix the order
print(my_fancy_calculation(third=1, first=3, second=2))

# You can mix arguments and keyword arguments but you have to start with arguments
print(my_fancy_calculation(3, third=1, second=2))

# %% [markdown]
# Note that this is the absolute minimal. I skipped three key things: array (similar to list but used differently), dictionary (similar to list but storing data differently), and class (objective-oriented programming: it's basically a way to organize attributes and functions)
